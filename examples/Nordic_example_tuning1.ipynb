# %% [markdown]
# ### Load lib

# %%
import numpy as np
import PyRAMSES

# %% [markdown]
# #### Load Models

# %%
from examples_models import end_simulation
from examples_models import move_file
from examples_models import sfc

# %% [markdown]
# #### Load a simulator instance

# %%
ram = PyRAMSES.sim()

# %% [markdown]
# #### Load saved test-case & Add more observation(s)

# %%
case = PyRAMSES.cfg('cmd.txt')  
case.addRunObs('MS g2')  # will plot a frequency-time diagram by bus g2
#case.addRunObs('BPO g6-1042')  # will plot a power (power output)-time diagram by g6
#case.addRunObs('BPO g7-1043')  # will plot a power (power output)-time diagram by g7
#case.addRunObs('BPO g14-4042')  # will plot a power (power output)-time diagram by g14
#case.addRunObs('BPO g15-4047')  # will plot a power (power output)-time diagram by g15
#case.addRunObs('BPO g16-4051')  # will plot a power (power output)-time diagram by g16

# %% [markdown]
# ### Tuning

# %%
if __name__ == '__main__':
    
    '''parameters
    Args:
        flagTd (string): flag whether communication delays are the same or not
        prepared_folder_address (string): cur files' new folder (the folder is parallel with ../examples)
        breaker (string): the name of generator you want to disconnection
        monitor (string): through it get the frequency of the system
        list_of_gens: whose power will be changed to increase/decrease the frequency in the sys
        weight_of_gens: defined how much a selected generator should output (according to Pnom)
        agcTimeStep: time step
    '''

    ######### parameters #########
    start_time = 150.0
    end_time = 390.0
    agcTimeStep = 1.0
    monitor = ['g2']
    breaker = 'g9'  # (dst file)
    list_of_gens = ['g6', 'g7', 'g14', 'g15', 'g16']
    weight_of_gens = [8,16,32/7,8/3,32/7]
    prepared_folder_address = 'D:/OneDrive - University of Leeds/Nordic/5.1'

    #### tuning delay & kp & ki: ####
    flagTd = 'ones'
    
    for td in np.arange(0.01, 0.22, 0.01):  # td: 0.01~0.21s
        list_of_td = td * np.ones(5)
        for kp in np.arange(0.1, 140.2, 10.0):  # kp: 0.1~140.1, step: 10
            for ki in np.arange(0.1, 10.2, 1.0):  # ki: 0.1~10.1, step: 1
                
                kp = "{0:.2f}".format(round(float(kp),2))
                ki = "{0:.2f}".format(round(float(ki),2))
                td = "{0:.2f}".format(round(float(td),2))
                
                print("kp = " + str(kp))
                print("ki = " + str(ki))
                print("td = " + str(td))

                #### Run sfc: ####
                sfc(ram, case, start_time, end_time, agcTimeStep, monitor, kp, ki, list_of_gens, weight_of_gens, list_of_td, prepared_folder_address, breaker, flagTd)
                pass
            pass
# Out:
# kp = 0.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 1.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 2.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 3.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 4.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 5.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 6.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 7.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 8.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 9.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 10.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 7.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 8.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 9.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 10.10
# td = 0.01
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 70.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 80.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 90.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 100.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 110.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 120.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 130.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 0.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 1.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 2.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 3.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 4.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 5.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 6.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 7.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 8.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 9.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 140.10
# ki = 10.10
# td = 0.01
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 0.10
# td = 0.02
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 1.10
# td = 0.02
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 2.10
# td = 0.02
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 3.10
# td = 0.02
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 4.10
# td = 0.02
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 5.10
# td = 0.02
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 0.10
# ki = 6.10
# td = 0.02
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# ...
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 4.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 5.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 6.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 7.10
# td = 0.11
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 8.10
# td = 0.11
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 9.10
# td = 0.11
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 10.10
# ki = 10.10
# td = 0.11
# RAMSES error => break, ready to kill gnuplot
# kill gnuplot successfully
# skip endSim()
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 0.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 1.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 2.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 3.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 4.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 5.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 6.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 7.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 8.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 9.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 20.10
# ki = 10.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 0.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 1.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 2.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 3.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 4.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 5.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 6.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 7.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 8.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 9.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 30.10
# ki = 10.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 0.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 1.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 2.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 3.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 4.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 5.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 6.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 7.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 8.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 9.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 40.10
# ki = 10.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 0.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 1.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 2.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 3.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 4.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 5.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 6.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 7.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 8.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 9.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 50.10
# ki = 10.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# delete temp_display(_).cur successfully
# delete trace: cont, disc, init, output successfully
#
# kp = 60.10
# ki = 0.10
# td = 0.11
# kill gnuplot successfully
# endSim() successfully
# delete ram & case successfully
# re-write cur successfully
# copy cur successfully
# rename cur successfully
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-2757dbc4a93a> in <module>
#      39
#      40                 #### Run sfc: ####
# ---> 41                 sfc(ram, case, start_time, end_time, agcTimeStep, monitor, kp, ki, list_of_gens, weight_of_gens, list_of_td, prepared_folder_address, breaker, flagTd)
#      42                 pass
#      43             pass
#
# ~\Desktop\GitHub\Nordic-test-system\examples\examples_models.py in sfc(ram, case, start_time, end_time, agcTimeStep, monitor, kp, ki, list_of_gens, weight_of_gens, list_of_td, prepared_folder_address, breaker, flagTd)
#      97         ######### end simulation & move files: #########
#      98         end_simulation(ram, case, flag)
# ---> 99         move_file(prepared_folder_address, flagTd, breaker, kp, ki, list_of_gens, list_of_td)
#     100
#     101
#
# ~\Desktop\GitHub\Nordic-test-system\examples\examples_models.py in move_file(prepared_folder_address, flagTd, breaker, kp, ki, list_of_gens, list_of_td)
#     201         ######### delete cur & trace files #########
#     202         # Delete cur files in public folder
# --> 203         os.unlink("temp_display.cur")
#     204         os.unlink("temp_display_.cur")
#     205         print("delete temp_display(_).cur successfully")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'temp_display.cur'
