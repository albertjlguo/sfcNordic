# %%
import numpy as np
import pandas as pd
import csv

# %%
kp = []
ki = []
settling_time = []

# %%
with open('ori.csv', 'r') as f:
    reader = csv.reader(f)
    datas = list(reader)

# %%
'''
Input: ori.csv file
Output: rank_average_settling_time.csv
Function: Calculate all the settleing time and average them
Tips: If one of the settling time is out of the range of 240 sec,
      results will be infinite (999999), for the specific kp & ki.
'''

for float_kp in np.arange(0.1, 300.2, 5):
    for float_ki in np.arange(0.1, 15.2, 1):

        print("------------------------------------------------------")
        float_kp = "{0:.2f}".format(round(float_kp,2))
        float_kp = float(float_kp)
        print("kp = " + str(float_kp))
        float_ki = "{0:.2f}".format(round(float_ki,2))
        float_ki = float(float_ki)
        print("ki = " + str(float_ki))

        i = 0
        settlingTime = 0.0
        for data in datas:
            if data[0] == str(float_kp) and data[1] == str(float_ki):
                i += 1
                print("\ni = " + str(i) + ":")
                print("Delay = " + data[2] + "sec")
                try:
                    print("Single settling time = " + data[3])
                    settlingTime += float(data[3])
                except ValueError:
                    print("Single settling time = empty => 999999")
                    settlingTime += 999999
                print("Accumulative settling time = " + str(settlingTime))

        print("i = " + str(i))
        if i == 0:
            settlingTime = 999999
        else:
            settlingTime = settlingTime/i
            settlingTime = "{0:.4f}".format(round(settlingTime,4))
            settlingTime = float(settlingTime)
        print("Average settling time = " + str(settlingTime) + "\n")
        kp.append(float_kp)
        ki.append(float_ki)
        settling_time.append(settlingTime)
# Out:
# ------------------------------------------------------
# kp = 0.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 0.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 0.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 0.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 0.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 5.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 5.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 5.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 5.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 5.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 10.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 10.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 10.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 10.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 10.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 15.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 52.7208
# Accumulative settling time = 52.7208
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 52.7908
# Accumulative settling time = 105.51159999999999
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 52.8408
# Accumulative settling time = 158.3524
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 52.8308
# Accumulative settling time = 211.1832
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 52.8808
# Accumulative settling time = 264.064
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 52.8508
# Accumulative settling time = 316.9148
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 52.8808
# Accumulative settling time = 369.79560000000004
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 52.8508
# Accumulative settling time = 422.6464
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 52.8808
# Accumulative settling time = 475.52720000000005
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 52.8508
# Accumulative settling time = 528.378
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 52.8808
# Accumulative settling time = 581.2588000000001
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 52.8508
# Accumulative settling time = 634.1096000000001
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 52.8808
# Accumulative settling time = 686.9904000000001
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 52.8308
# Accumulative settling time = 739.8212000000001
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 52.8808
# Accumulative settling time = 792.7020000000001
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 52.8308
# Accumulative settling time = 845.5328000000001
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 52.8608
# Accumulative settling time = 898.3936000000001
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 52.8108
# Accumulative settling time = 951.2044000000001
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 52.8408
# Accumulative settling time = 1004.0452
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 52.7908
# Accumulative settling time = 1056.836
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 52.8408
# Accumulative settling time = 1109.6768
# i = 21
# Average settling time = 52.8418
#
# ------------------------------------------------------
# kp = 15.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 15.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 15.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 15.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 20.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 48.5208
# Accumulative settling time = 48.5208
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 48.5708
# Accumulative settling time = 97.0916
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 48.6008
# Accumulative settling time = 145.6924
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 48.5908
# Accumulative settling time = 194.2832
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 48.6008
# Accumulative settling time = 242.884
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 48.5708
# Accumulative settling time = 291.4548
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 48.5808
# Accumulative settling time = 340.0356
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 48.5508
# Accumulative settling time = 388.58639999999997
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 48.5608
# Accumulative settling time = 437.1472
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 48.5108
# Accumulative settling time = 485.658
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 48.5208
# Accumulative settling time = 534.1788
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 48.4708
# Accumulative settling time = 582.6496
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 48.4808
# Accumulative settling time = 631.1304
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 48.4308
# Accumulative settling time = 679.5612
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 48.4408
# Accumulative settling time = 728.002
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 48.3708
# Accumulative settling time = 776.3728
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 48.3808
# Accumulative settling time = 824.7536
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 48.3308
# Accumulative settling time = 873.0844
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 48.3208
# Accumulative settling time = 921.4051999999999
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 48.2708
# Accumulative settling time = 969.6759999999999
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 48.2808
# Accumulative settling time = 1017.9567999999999
# i = 21
# Average settling time = 48.4741
#
# ------------------------------------------------------
# kp = 20.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 90.6208
# Accumulative settling time = 90.6208
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 90.7108
# Accumulative settling time = 181.3316
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 90.7808
# Accumulative settling time = 272.1124
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 90.8318
# Accumulative settling time = 362.94419999999997
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 90.9008
# Accumulative settling time = 453.84499999999997
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 90.9318
# Accumulative settling time = 544.7768
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 99.788
# Accumulative settling time = 644.5648
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 99.88566667
# Accumulative settling time = 744.45046667
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 99.956
# Accumulative settling time = 844.40646667
# i = 9
# Average settling time = 93.8229
#
# ------------------------------------------------------
# kp = 20.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 20.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 20.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 25.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 74.586
# Accumulative settling time = 74.586
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 74.57
# Accumulative settling time = 149.156
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 74.54
# Accumulative settling time = 223.69600000000003
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 74.551
# Accumulative settling time = 298.247
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 73.809
# Accumulative settling time = 372.05600000000004
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 74.551
# Accumulative settling time = 446.607
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 73.82133333
# Accumulative settling time = 520.42833333
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 73.839
# Accumulative settling time = 594.2673333299999
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 73.83466667
# Accumulative settling time = 668.102
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 73.85
# Accumulative settling time = 741.952
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 73.848
# Accumulative settling time = 815.8
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 73.86
# Accumulative settling time = 889.66
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 73.86133333
# Accumulative settling time = 963.52133333
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 73.87233333
# Accumulative settling time = 1037.39366666
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 73.868
# Accumulative settling time = 1111.26166666
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 73.879
# Accumulative settling time = 1185.1406666599999
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 73.87466667
# Accumulative settling time = 1259.0153333299997
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 73.88566667
# Accumulative settling time = 1332.9009999999998
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 73.88133333
# Accumulative settling time = 1406.7823333299998
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 73.89233333
# Accumulative settling time = 1480.6746666599997
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 73.888
# Accumulative settling time = 1554.5626666599996
# i = 21
# Average settling time = 74.0268
#
# ------------------------------------------------------
# kp = 25.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 72.824
# Accumulative settling time = 72.824
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 73.486
# Accumulative settling time = 146.31
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 73.6096
# Accumulative settling time = 219.9196
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 73.667
# Accumulative settling time = 293.5866
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 73.74171429
# Accumulative settling time = 367.32831429
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 73.77842857
# Accumulative settling time = 441.10674286
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 73.84742857
# Accumulative settling time = 514.95417143
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 73.86128571
# Accumulative settling time = 588.81545714
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 73.936
# Accumulative settling time = 662.7514571400001
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 73.97271429
# Accumulative settling time = 736.7241714300001
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 74.017
# Accumulative settling time = 810.7411714300001
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 74.04466667
# Accumulative settling time = 884.7858381000001
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 74.134
# Accumulative settling time = 958.9198381000001
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 74.127
# Accumulative settling time = 1033.0468381
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 74.236
# Accumulative settling time = 1107.2828381000002
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 74.227
# Accumulative settling time = 1181.5098381000003
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 74.52
# Accumulative settling time = 1256.0298381000002
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 74.471
# Accumulative settling time = 1330.5008381000002
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 74.59466667
# Accumulative settling time = 1405.0955047700002
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 74.57233333
# Accumulative settling time = 1479.6678381000002
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 82.4008
# Accumulative settling time = 1562.0686381
# i = 21
# Average settling time = 74.3842
#
# ------------------------------------------------------
# kp = 25.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 25.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 25.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 30.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 42.7808
# Accumulative settling time = 42.7808
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 42.7908
# Accumulative settling time = 85.57159999999999
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 42.7808
# Accumulative settling time = 128.3524
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 42.7708
# Accumulative settling time = 171.1232
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 42.7608
# Accumulative settling time = 213.88400000000001
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 42.7508
# Accumulative settling time = 256.63480000000004
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 42.7408
# Accumulative settling time = 299.3756
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 42.7108
# Accumulative settling time = 342.0864
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 42.7008
# Accumulative settling time = 384.78720000000004
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 42.6508
# Accumulative settling time = 427.43800000000005
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 42.6408
# Accumulative settling time = 470.07880000000006
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 42.5908
# Accumulative settling time = 512.6696000000001
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 42.5408
# Accumulative settling time = 555.2104
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 42.4508
# Accumulative settling time = 597.6612
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 42.4008
# Accumulative settling time = 640.062
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 42.3108
# Accumulative settling time = 682.3728
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 42.2808
# Accumulative settling time = 724.6536
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 42.2308
# Accumulative settling time = 766.8844
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 42.20024
# Accumulative settling time = 809.08464
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 42.1688
# Accumulative settling time = 851.2534400000001
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 42.1488
# Accumulative settling time = 893.4022400000001
# i = 21
# Average settling time = 42.543
#
# ------------------------------------------------------
# kp = 30.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 59.5408
# Accumulative settling time = 59.5408
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 59.5908
# Accumulative settling time = 119.13159999999999
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 59.6808
# Accumulative settling time = 178.8124
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 59.7308
# Accumulative settling time = 238.5432
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 59.8208
# Accumulative settling time = 298.36400000000003
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 59.8308
# Accumulative settling time = 358.19480000000004
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 59.9008
# Accumulative settling time = 418.09560000000005
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 59.9308
# Accumulative settling time = 478.0264
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 59.9808
# Accumulative settling time = 538.0072
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 59.98992
# Accumulative settling time = 597.99712
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 60.0688
# Accumulative settling time = 658.06592
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 60.0688
# Accumulative settling time = 718.13472
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 60.1244
# Accumulative settling time = 778.25912
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 60.1288
# Accumulative settling time = 838.38792
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 60.16024
# Accumulative settling time = 898.54816
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 60.1488
# Accumulative settling time = 958.6969600000001
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 60.2008
# Accumulative settling time = 1018.8977600000001
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 60.2108
# Accumulative settling time = 1079.1085600000001
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 60.2608
# Accumulative settling time = 1139.3693600000001
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 60.21024
# Accumulative settling time = 1199.5796
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 60.2408
# Accumulative settling time = 1259.8204
# i = 21
# Average settling time = 59.9914
#
# ------------------------------------------------------
# kp = 30.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 30.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 30.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 35.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 40.7608
# Accumulative settling time = 40.7608
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 40.7708
# Accumulative settling time = 81.5316
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 40.7608
# Accumulative settling time = 122.2924
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 40.7508
# Accumulative settling time = 163.0432
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 40.7408
# Accumulative settling time = 203.78400000000002
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 40.7264
# Accumulative settling time = 244.5104
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 40.7008
# Accumulative settling time = 285.2112
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 40.6708
# Accumulative settling time = 325.882
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 40.6608
# Accumulative settling time = 366.5428
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 40.6108
# Accumulative settling time = 407.1536
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 40.5808
# Accumulative settling time = 447.7344
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 40.5108
# Accumulative settling time = 488.2452
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 40.4208
# Accumulative settling time = 528.666
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 40.3108
# Accumulative settling time = 568.9768
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 40.2808
# Accumulative settling time = 609.2576
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 40.2308
# Accumulative settling time = 649.4884000000001
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 40.2008
# Accumulative settling time = 689.6892
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 40.1688
# Accumulative settling time = 729.8580000000001
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 40.1488
# Accumulative settling time = 770.0068000000001
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 40.1244
# Accumulative settling time = 810.1312000000001
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 40.1088
# Accumulative settling time = 850.2400000000001
# i = 21
# Average settling time = 40.4876
#
# ------------------------------------------------------
# kp = 35.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 49.456
# Accumulative settling time = 49.456
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 49.44666667
# Accumulative settling time = 98.90266667
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 49.42333333
# Accumulative settling time = 148.326
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 49.35133333
# Accumulative settling time = 197.67733333
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 49.289
# Accumulative settling time = 246.96633333
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 49.19333333
# Accumulative settling time = 296.15966665999997
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 49.1705
# Accumulative settling time = 345.33016666
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 49.12090909
# Accumulative settling time = 394.45107575
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 49.10618462
# Accumulative settling time = 443.55726037
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 49.07057143
# Accumulative settling time = 492.62783179999997
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 49.0605
# Accumulative settling time = 541.6883318
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 54.2708
# Accumulative settling time = 595.9591318
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 54.7208
# Accumulative settling time = 650.6799318000001
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 54.9108
# Accumulative settling time = 705.5907318000001
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 55.0688
# Accumulative settling time = 760.6595318000001
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 55.3108
# Accumulative settling time = 815.9703318
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 55.6208
# Accumulative settling time = 871.5911318000001
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 55.7308
# Accumulative settling time = 927.3219318000001
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 55.8808
# Accumulative settling time = 983.2027318000002
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 55.8708
# Accumulative settling time = 1039.0735318000002
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 55.9808
# Accumulative settling time = 1095.0543318000002
# i = 21
# Average settling time = 52.1454
#
# ------------------------------------------------------
# kp = 35.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 35.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 35.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 40.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 39.02024
# Accumulative settling time = 39.02024
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 39.03024
# Accumulative settling time = 78.05048
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 39.03044
# Accumulative settling time = 117.08091999999999
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 39.0088
# Accumulative settling time = 156.08972
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 38.99552
# Accumulative settling time = 195.08524
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 38.9764
# Accumulative settling time = 234.06164
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 38.9764
# Accumulative settling time = 273.03804
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 38.9564
# Accumulative settling time = 311.99444000000005
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 38.9464
# Accumulative settling time = 350.94084000000004
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 38.9264
# Accumulative settling time = 389.86724000000004
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 38.9164
# Accumulative settling time = 428.78364000000005
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 38.8964
# Accumulative settling time = 467.6800400000001
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 38.8864
# Accumulative settling time = 506.56644000000006
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 38.8664
# Accumulative settling time = 545.43284
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 38.8564
# Accumulative settling time = 584.2892400000001
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 38.8364
# Accumulative settling time = 623.1256400000001
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 38.8164
# Accumulative settling time = 661.9420400000001
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 38.7864
# Accumulative settling time = 700.7284400000001
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 38.7664
# Accumulative settling time = 739.4948400000001
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 38.7264
# Accumulative settling time = 778.2212400000001
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 38.6808
# Accumulative settling time = 816.90204
# i = 21
# Average settling time = 38.9001
#
# ------------------------------------------------------
# kp = 40.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 46.68186667
# Accumulative settling time = 46.68186667
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 46.7052
# Accumulative settling time = 93.38706667
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 46.72375
# Accumulative settling time = 140.11081667
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 46.72625
# Accumulative settling time = 186.83706666999998
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 46.74125
# Accumulative settling time = 233.57831667
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 46.73375
# Accumulative settling time = 280.31206667
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 46.74658824
# Accumulative settling time = 327.05865491
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 46.72952941
# Accumulative settling time = 373.78818431999997
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 46.74188235
# Accumulative settling time = 420.53006667
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 46.73305882
# Accumulative settling time = 467.26312549
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 46.74133333
# Accumulative settling time = 514.00445882
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 46.72129412
# Accumulative settling time = 560.72575294
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 46.72423529
# Accumulative settling time = 607.44998823
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 46.705
# Accumulative settling time = 654.1549882300001
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 46.70375
# Accumulative settling time = 700.8587382300001
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 46.67828571
# Accumulative settling time = 747.53702394
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 51.5808
# Accumulative settling time = 799.11782394
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 51.7908
# Accumulative settling time = 850.90862394
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 52.0488
# Accumulative settling time = 902.95742394
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 52.21024
# Accumulative settling time = 955.16766394
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 52.5608
# Accumulative settling time = 1007.72846394
# i = 21
# Average settling time = 47.9871
#
# ------------------------------------------------------
# kp = 40.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 40.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 40.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 45.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 37.77493333
# Accumulative settling time = 37.77493333
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 37.78493333
# Accumulative settling time = 75.55986666000001
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 37.78826667
# Accumulative settling time = 113.34813333000001
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 37.78493333
# Accumulative settling time = 151.13306666
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 37.7864
# Accumulative settling time = 188.91946666
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 37.7764
# Accumulative settling time = 226.69586666
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 37.7764
# Accumulative settling time = 264.47226666
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 37.75826667
# Accumulative settling time = 302.23053333
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 37.7564
# Accumulative settling time = 339.98693333
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 37.73826667
# Accumulative settling time = 377.7252
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 37.7364
# Accumulative settling time = 415.4616
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 37.7116
# Accumulative settling time = 453.17319999999995
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 37.7064
# Accumulative settling time = 490.8796
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 37.6708
# Accumulative settling time = 528.5504
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 37.6564
# Accumulative settling time = 566.2067999999999
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 37.6108
# Accumulative settling time = 603.8176
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 37.5808
# Accumulative settling time = 641.3983999999999
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 37.4908
# Accumulative settling time = 678.8892
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 37.4408
# Accumulative settling time = 716.3299999999999
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 40.7316
# Accumulative settling time = 757.0615999999999
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 40.9256
# Accumulative settling time = 797.9871999999999
# i = 21
# Average settling time = 37.9994
#
# ------------------------------------------------------
# kp = 45.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 43.88266667
# Accumulative settling time = 43.88266667
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 43.941
# Accumulative settling time = 87.82366667
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 43.9948
# Accumulative settling time = 131.81846667
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 44.0335
# Accumulative settling time = 175.85196667
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 44.098
# Accumulative settling time = 219.94996666999998
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 44.108
# Accumulative settling time = 264.05796667
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 44.18
# Accumulative settling time = 308.23796667
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 44.17333333
# Accumulative settling time = 352.4113
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 44.259
# Accumulative settling time = 396.6703
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 44.2396
# Accumulative settling time = 440.9099
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 44.324
# Accumulative settling time = 485.2339
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 44.25666667
# Accumulative settling time = 529.49056667
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 44.354
# Accumulative settling time = 573.8445666700001
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 44.354
# Accumulative settling time = 618.1985666700001
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 49.0288
# Accumulative settling time = 667.2273666700002
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 49.5708
# Accumulative settling time = 716.7981666700001
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 49.8008
# Accumulative settling time = 766.5989666700001
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 49.8908
# Accumulative settling time = 816.4897666700001
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 50.0688
# Accumulative settling time = 866.5585666700001
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 50.1888
# Accumulative settling time = 916.7473666700001
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 50.4408
# Accumulative settling time = 967.1881666700001
# i = 21
# Average settling time = 46.0566
#
# ------------------------------------------------------
# kp = 45.1
# ki = 10.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 57.58933333
# Accumulative settling time = 57.58933333
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 57.65971429
# Accumulative settling time = 115.24904762
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 57.7175
# Accumulative settling time = 172.96654762
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 57.75
# Accumulative settling time = 230.71654762
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 57.80305882
# Accumulative settling time = 288.51960644
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 57.82364706
# Accumulative settling time = 346.3432535
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 57.87466667
# Accumulative settling time = 404.21792017
# i = 7
# Average settling time = 57.7454
#
# ------------------------------------------------------
# kp = 45.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 45.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 50.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 36.78826667
# Accumulative settling time = 36.78826667
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 36.79826667
# Accumulative settling time = 73.58653333999999
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 36.8016
# Accumulative settling time = 110.38813334
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 36.7964
# Accumulative settling time = 147.18453334
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 36.79493333
# Accumulative settling time = 183.97946667
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 36.78493333
# Accumulative settling time = 220.7644
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 36.7816
# Accumulative settling time = 257.546
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 36.7716
# Accumulative settling time = 294.31759999999997
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 36.76826667
# Accumulative settling time = 331.08586667
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 36.7516
# Accumulative settling time = 367.83746666999997
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 36.7464
# Accumulative settling time = 404.58386666999996
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 36.7264
# Accumulative settling time = 441.31026667
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 39.63466667
# Accumulative settling time = 480.94493334
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 39.864
# Accumulative settling time = 520.80893334
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 40.6136
# Accumulative settling time = 561.42253334
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 40.698
# Accumulative settling time = 602.12053334
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 40.79454545
# Accumulative settling time = 642.9150787899999
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 40.84766667
# Accumulative settling time = 683.7627454599999
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 40.92433333
# Accumulative settling time = 724.6870787899999
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 40.971
# Accumulative settling time = 765.6580787899999
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 41.01542857
# Accumulative settling time = 806.6735073599999
# i = 21
# Average settling time = 38.413
#
# ------------------------------------------------------
# kp = 50.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 41.81
# Accumulative settling time = 41.81
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 41.88261538
# Accumulative settling time = 83.69261538
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 41.95766667
# Accumulative settling time = 125.65028205000002
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 42.018
# Accumulative settling time = 167.66828205000002
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 42.1376
# Accumulative settling time = 209.80588205
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 42.20466667
# Accumulative settling time = 252.01054872
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 42.456
# Accumulative settling time = 294.46654872
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 42.483
# Accumulative settling time = 336.94954872
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 46.7408
# Accumulative settling time = 383.69034872
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 47.5308
# Accumulative settling time = 431.22114872
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 47.7408
# Accumulative settling time = 478.96194871999995
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 47.8308
# Accumulative settling time = 526.79274872
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 48.0088
# Accumulative settling time = 574.8015487199999
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 48.15024
# Accumulative settling time = 622.95178872
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 48.4808
# Accumulative settling time = 671.43258872
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 48.5908
# Accumulative settling time = 720.02338872
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 48.7208
# Accumulative settling time = 768.74418872
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 48.7708
# Accumulative settling time = 817.51498872
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 48.8664
# Accumulative settling time = 866.38138872
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 48.9308
# Accumulative settling time = 915.31218872
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 48.99552
# Accumulative settling time = 964.3077087199999
# i = 21
# Average settling time = 45.9194
#
# ------------------------------------------------------
# kp = 50.1
# ki = 10.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 54.92
# Accumulative settling time = 54.92
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 55.376
# Accumulative settling time = 110.29599999999999
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 55.533
# Accumulative settling time = 165.829
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 55.5988
# Accumulative settling time = 221.4278
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 55.671
# Accumulative settling time = 277.0988
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 55.71114286
# Accumulative settling time = 332.80994286
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 55.76986667
# Accumulative settling time = 388.57980953
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 55.8
# Accumulative settling time = 444.37980953
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 55.85717647
# Accumulative settling time = 500.236986
# i = 9
# Average settling time = 55.5819
#
# ------------------------------------------------------
# kp = 50.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 50.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 55.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 35.8142
# Accumulative settling time = 35.8142
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 35.8292
# Accumulative settling time = 71.6434
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 35.8392
# Accumulative settling time = 107.48259999999999
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 35.8392
# Accumulative settling time = 143.3218
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 35.8492
# Accumulative settling time = 179.171
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 38.484
# Accumulative settling time = 217.655
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 38.68
# Accumulative settling time = 256.335
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 38.7956
# Accumulative settling time = 295.13059999999996
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 39.59333333
# Accumulative settling time = 334.72393332999997
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 39.6855
# Accumulative settling time = 374.40943332999996
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 39.7828
# Accumulative settling time = 414.19223332999997
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 39.8448
# Accumulative settling time = 454.03703333
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 39.9328
# Accumulative settling time = 493.96983333
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 39.99415
# Accumulative settling time = 533.96398333
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 40.11466667
# Accumulative settling time = 574.07865
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 40.204
# Accumulative settling time = 614.28265
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 40.524
# Accumulative settling time = 654.80665
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 40.59457143
# Accumulative settling time = 695.40122143
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 40.68545455
# Accumulative settling time = 736.08667598
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 40.71933333
# Accumulative settling time = 776.80600931
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 40.78
# Accumulative settling time = 817.58600931
# i = 21
# Average settling time = 38.9327
#
# ------------------------------------------------------
# kp = 55.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 45.5008
# Accumulative settling time = 45.5008
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 45.8708
# Accumulative settling time = 91.3716
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 46.1008
# Accumulative settling time = 137.4724
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 46.3708
# Accumulative settling time = 183.8432
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 46.5208
# Accumulative settling time = 230.364
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 46.6108
# Accumulative settling time = 276.9748
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 46.7008
# Accumulative settling time = 323.67560000000003
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 46.7708
# Accumulative settling time = 370.44640000000004
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 46.8608
# Accumulative settling time = 417.3072
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 46.9308
# Accumulative settling time = 464.238
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 47.0488
# Accumulative settling time = 511.28679999999997
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 47.1088
# Accumulative settling time = 558.3956
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 47.2808
# Accumulative settling time = 605.6764
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 47.3908
# Accumulative settling time = 653.0672
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 47.5608
# Accumulative settling time = 700.6279999999999
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 47.6108
# Accumulative settling time = 748.2388
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 47.7008
# Accumulative settling time = 795.9395999999999
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 47.7308
# Accumulative settling time = 843.6704
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 47.8364
# Accumulative settling time = 891.5068
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 47.8564
# Accumulative settling time = 939.3632
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 47.9164
# Accumulative settling time = 987.2796
# i = 21
# Average settling time = 47.0133
#
# ------------------------------------------------------
# kp = 55.1
# ki = 10.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 52.788
# Accumulative settling time = 52.788
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 52.9076
# Accumulative settling time = 105.6956
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 53.469
# Accumulative settling time = 159.1646
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 53.5655
# Accumulative settling time = 212.7301
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 53.66
# Accumulative settling time = 266.39009999999996
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 53.706
# Accumulative settling time = 320.0961
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 53.78114286
# Accumulative settling time = 373.87724285999997
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 53.81685714
# Accumulative settling time = 427.6941
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 53.88453333
# Accumulative settling time = 481.57863333
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 53.9212
# Accumulative settling time = 535.49983333
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 53.9952
# Accumulative settling time = 589.49503333
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 54.02072727
# Accumulative settling time = 643.5157605999999
# i = 12
# Average settling time = 53.6263
#
# ------------------------------------------------------
# kp = 55.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 55.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 60.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 38.3816
# Accumulative settling time = 38.3816
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 38.52288889
# Accumulative settling time = 76.90448889
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 38.61818182
# Accumulative settling time = 115.52267071
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 38.68266667
# Accumulative settling time = 154.20533738
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 38.766
# Accumulative settling time = 192.97133738
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 38.81766667
# Accumulative settling time = 231.78900405
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 38.90545455
# Accumulative settling time = 270.69445859999996
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 38.96511111
# Accumulative settling time = 309.65956970999997
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 39.124
# Accumulative settling time = 348.78356971
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 39.47133333
# Accumulative settling time = 388.25490304
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 39.60177778
# Accumulative settling time = 427.85668082
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 39.65433333
# Accumulative settling time = 467.51101415
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 39.7232
# Accumulative settling time = 507.23421415
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 39.76
# Accumulative settling time = 546.9942141500001
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 39.81466667
# Accumulative settling time = 586.80888082
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 39.8444
# Accumulative settling time = 626.65328082
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 39.8934
# Accumulative settling time = 666.54668082
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 39.91857143
# Accumulative settling time = 706.46525225
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 39.96327273
# Accumulative settling time = 746.42852498
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 39.98506
# Accumulative settling time = 786.41358498
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 40.03936842
# Accumulative settling time = 826.4529534
# i = 21
# Average settling time = 39.3549
#
# ------------------------------------------------------
# kp = 60.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 45.5408
# Accumulative settling time = 45.5408
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 45.6308
# Accumulative settling time = 91.1716
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 45.7208
# Accumulative settling time = 136.8924
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 45.7708
# Accumulative settling time = 182.66320000000002
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 45.8408
# Accumulative settling time = 228.50400000000002
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 45.8908
# Accumulative settling time = 274.39480000000003
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 45.9608
# Accumulative settling time = 320.35560000000004
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 46.0088
# Accumulative settling time = 366.36440000000005
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 46.1208
# Accumulative settling time = 412.4852000000001
#
# i = 10:
# Delay = 0.1sec
# Single settling time = 46.1908
# Accumulative settling time = 458.6760000000001
#
# i = 11:
# Delay = 0.11sec
# Single settling time = 46.3808
# Accumulative settling time = 505.0568000000001
#
# i = 12:
# Delay = 0.12sec
# Single settling time = 46.4508
# Accumulative settling time = 551.5076000000001
#
# i = 13:
# Delay = 0.13sec
# Single settling time = 46.5808
# Accumulative settling time = 598.0884000000001
#
# i = 14:
# Delay = 0.14sec
# Single settling time = 46.6108
# Accumulative settling time = 644.6992000000001
#
# i = 15:
# Delay = 0.15sec
# Single settling time = 46.7164
# Accumulative settling time = 691.4156000000002
#
# i = 16:
# Delay = 0.16sec
# Single settling time = 46.7364
# Accumulative settling time = 738.1520000000002
#
# i = 17:
# Delay = 0.17sec
# Single settling time = 46.7864
# Accumulative settling time = 784.9384000000001
#
# i = 18:
# Delay = 0.18sec
# Single settling time = 46.8064
# Accumulative settling time = 831.7448000000002
#
# i = 19:
# Delay = 0.19sec
# Single settling time = 46.8564
# Accumulative settling time = 878.6012000000002
#
# i = 20:
# Delay = 0.2sec
# Single settling time = 46.8664
# Accumulative settling time = 925.4676000000002
#
# i = 21:
# Delay = 0.21sec
# Single settling time = 46.9064
# Accumulative settling time = 972.3740000000001
# i = 21
# Average settling time = 46.3035
#
# ------------------------------------------------------
# kp = 60.1
# ...
# kp = 220.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 220.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 225.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 47.751
# Accumulative settling time = 47.751
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 47.806
# Accumulative settling time = 95.55699999999999
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 47.9048
# Accumulative settling time = 143.46179999999998
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 48.32828571
# Accumulative settling time = 191.79008570999997
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 48.37717647
# Accumulative settling time = 240.16726217999997
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 50.3508
# Accumulative settling time = 290.51806217999996
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 50.7208
# Accumulative settling time = 341.23886217999996
#
# i = 8:
# Delay = 0.08sec
# Single settling time = 53.594
# Accumulative settling time = 394.83286217999995
#
# i = 9:
# Delay = 0.09sec
# Single settling time = 53.80266667
# Accumulative settling time = 448.63552884999996
# i = 9
# Average settling time = 49.8484
#
# ------------------------------------------------------
# kp = 225.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 50.4764
# Accumulative settling time = 50.4764
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 50.5064
# Accumulative settling time = 100.9828
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 50.5408
# Accumulative settling time = 151.5236
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 50.7764
# Accumulative settling time = 202.29999999999998
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 50.8164
# Accumulative settling time = 253.1164
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 53.4105
# Accumulative settling time = 306.5269
# i = 6
# Average settling time = 51.0878
#
# ------------------------------------------------------
# kp = 225.1
# ki = 10.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 50.6864
# Accumulative settling time = 50.6864
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 50.7364
# Accumulative settling time = 101.4228
# i = 2
# Average settling time = 50.7114
#
# ------------------------------------------------------
# kp = 225.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 225.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 230.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 47.65756522
# Accumulative settling time = 47.65756522
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 47.69713043
# Accumulative settling time = 95.35469565
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 47.75234783
# Accumulative settling time = 143.10704348
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 50.1108
# Accumulative settling time = 193.21784348
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 50.3864
# Accumulative settling time = 243.60424348
#
# i = 6:
# Delay = 0.06sec
# Single settling time = 50.5264
# Accumulative settling time = 294.13064348
#
# i = 7:
# Delay = 0.07sec
# Single settling time = 53.356
# Accumulative settling time = 347.48664348
# i = 7
# Average settling time = 49.6409
#
# ------------------------------------------------------
# kp = 230.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 50.3808
# Accumulative settling time = 50.3808
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 50.4464
# Accumulative settling time = 100.8272
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 50.5164
# Accumulative settling time = 151.3436
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 50.6164
# Accumulative settling time = 201.96
# i = 4
# Average settling time = 50.49
#
# ------------------------------------------------------
# kp = 230.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 230.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 230.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 235.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 47.56426667
# Accumulative settling time = 47.56426667
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 47.59981818
# Accumulative settling time = 95.16408485
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 49.2808
# Accumulative settling time = 144.44488485
#
# i = 4:
# Delay = 0.04sec
# Single settling time = 52.33
# Accumulative settling time = 196.77488484999998
#
# i = 5:
# Delay = 0.05sec
# Single settling time = 52.76177778
# Accumulative settling time = 249.53666262999997
# i = 5
# Average settling time = 49.9073
#
# ------------------------------------------------------
# kp = 235.1
# ki = 5.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 50.2008
# Accumulative settling time = 50.2008
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 50.2508
# Accumulative settling time = 100.4516
# i = 2
# Average settling time = 50.2258
#
# ------------------------------------------------------
# kp = 235.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 235.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 235.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 240.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 49.4608
# Accumulative settling time = 49.4608
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 49.5764
# Accumulative settling time = 99.0372
#
# i = 3:
# Delay = 0.03sec
# Single settling time = 52.184
# Accumulative settling time = 151.2212
# i = 3
# Average settling time = 50.4071
#
# ------------------------------------------------------
# kp = 240.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 240.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 240.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 240.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 245.1
# ki = 0.1
#
# i = 1:
# Delay = 0.01sec
# Single settling time = 51.788
# Accumulative settling time = 51.788
#
# i = 2:
# Delay = 0.02sec
# Single settling time = 51.9596
# Accumulative settling time = 103.7476
# i = 2
# Average settling time = 51.8738
#
# ------------------------------------------------------
# kp = 245.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 245.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 245.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 245.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 250.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 250.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 250.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 250.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 250.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 255.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 255.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 255.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 255.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 255.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 260.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 260.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 260.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 260.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 260.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 265.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 265.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 265.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 265.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 265.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 270.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 270.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 270.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 270.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 270.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 275.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 275.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 275.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 275.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 275.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 280.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 280.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 280.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 280.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 280.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 285.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 285.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 285.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 285.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 285.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 290.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 290.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 290.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 290.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 290.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 295.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 295.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 295.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 295.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 295.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 300.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 300.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 300.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 300.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 300.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 305.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 305.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 305.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 305.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 305.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 310.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 310.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 310.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 310.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 310.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 315.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 315.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 315.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 315.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 315.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 320.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 320.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 320.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 320.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 320.1
# ki = 20.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 325.1
# ki = 0.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 325.1
# ki = 5.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 325.1
# ki = 10.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 325.1
# ki = 15.1
# i = 0
# Average settling time = 999999
#
# ------------------------------------------------------
# kp = 325.1
# ki = 20.1
# i = 0
# Average settling time = 999999

# %%
print(kp)
print(ki)
print(settling_time)

# %%
raw_data = {'kp': kp, 'ki': ki, 'Average Settling Time (sec)': settling_time}
df = pd.DataFrame(raw_data, columns = ['kp', 'ki', 'Average Settling Time (sec)'])
df.to_csv('rank_average_settling_time.csv')
